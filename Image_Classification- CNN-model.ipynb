# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D

# %%
import pickle

X = pickle.load(open("X.pickle","rb"))
y = pickle.load(open("y.pickle","rb"))

# %%
X = X/255.0

# %%
import numpy as np

X1 = np.array(X)
y1 = np.array(y)

# %%
X.shape[1:]
# Out:
# (50, 50, 1)

# %%
model = Sequential()

model.add(Conv2D(64,(3,3), input_shape = X.shape[1:]))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,(3,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(64))
model.add(Dense(1))
model.add(Activation("sigmoid"))

model.compile(loss="binary_crossentropy", optimizer="adam", metrics = ["accuracy"])

model_result = model.fit(X1,y1, batch_size=32,epochs=20, validation_split=0.1)
# Out:
# Epoch 1/20
# 702/702 [==============================] - 48s 67ms/step - loss: 0.6837 - accuracy: 0.5629 - val_loss: 0.6203 - val_accuracy: 0.6649
# Epoch 2/20
# 702/702 [==============================] - 50s 72ms/step - loss: 0.5878 - accuracy: 0.6905 - val_loss: 0.5511 - val_accuracy: 0.7279
# Epoch 3/20
# 702/702 [==============================] - 45s 64ms/step - loss: 0.5186 - accuracy: 0.7492 - val_loss: 0.5415 - val_accuracy: 0.7339
# Epoch 4/20
# 702/702 [==============================] - 48s 69ms/step - loss: 0.4716 - accuracy: 0.7789 - val_loss: 0.5051 - val_accuracy: 0.7603
# Epoch 5/20
# 702/702 [==============================] - 55s 79ms/step - loss: 0.4333 - accuracy: 0.8011 - val_loss: 0.4788 - val_accuracy: 0.7711
# Epoch 6/20
# 702/702 [==============================] - 51s 73ms/step - loss: 0.4004 - accuracy: 0.8202 - val_loss: 0.4696 - val_accuracy: 0.7804
# Epoch 7/20
# ...

# %%
# save it as a h5 file


from tensorflow.keras.models import load_model

model.save('model_cat-dog.h5')

# %%
from tensorflow.keras.preprocessing.image import  load_img
from tensorflow.keras.preprocessing import image

# %%
# pic1 = load_img("3.jpg",target_size=(50, 50))
# pic1
import cv2
IMG_SIZE = 50
pic1_array = cv2.imread("3.jpg", cv2.IMREAD_GRAYSCALE)
new_array = cv2.resize(pic1_array,(IMG_SIZE,IMG_SIZE))

# %%
# new_array = new_array/255.0
print(new_array.shape)
img1_batch = np.expand_dims(new_array, axis=0)
print(img1_batch.shape)
uimg = np.resize(img1_batch,(1,50,50,1))
# Out:
# (50, 50)
# (1, 50, 50)

# %%
#img1_batch = img1_batch/255.0
uimg = uimg/255.0

# %%
pred1 = model.predict(uimg)

# %%
pred1
# Out:
# array([[0.07461515]], dtype=float32)

# %%
pic2_array = cv2.imread("7.jpg", cv2.IMREAD_GRAYSCALE)
new_array2 = cv2.resize(pic2_array,(IMG_SIZE,IMG_SIZE))

img2_batch = np.expand_dims(new_array2, axis=0)
uimg2 = np.resize(img2_batch,(1,50,50,1))

uimg2 = uimg2/255.0
pred2 = model.predict(uimg2)

pred2
# Out:
# array([[0.7288457]], dtype=float32)

# %%
pic2_array = cv2.imread("4.jpg", cv2.IMREAD_GRAYSCALE)
new_array2 = cv2.resize(pic2_array,(IMG_SIZE,IMG_SIZE))

img2_batch = np.expand_dims(new_array2, axis=0)
uimg2 = np.resize(img2_batch,(1,50,50,1))

uimg2 = uimg2/255.0
pred2 = model.predict(uimg2)

pred2
# Out:
# array([[0.00323129]], dtype=float32)

# %%
pic2_array = cv2.imread("test/5.jpg", cv2.IMREAD_GRAYSCALE)
new_array2 = cv2.resize(pic2_array,(IMG_SIZE,IMG_SIZE))

img2_batch = np.expand_dims(new_array2, axis=0)
uimg2 = np.resize(img2_batch,(1,50,50,1))

uimg2 = uimg2/255.0
pred2 = model.predict(uimg2)

pred2
# Out:
# array([[0.9925978]], dtype=float32)

# %%
sum=0
for i in range(0,12500) :
    photo = "PetImages/Cat/{}.jpg".format(i)
    try :
        pic_array = cv2.imread(photo, cv2.IMREAD_GRAYSCALE)
        new_array = cv2.resize(pic_array,(IMG_SIZE,IMG_SIZE))

        img_batch = np.expand_dims(new_array, axis=0)
        uimg = np.resize(img_batch,(1,50,50,1))

        uimg = uimg/255.0
        pred = model.predict(uimg)

        pred
        if pred[0][0]>0.5 : 
            print("{} is : cat".format(i))
            sum +=1
        else :
            print("{} is : dog".format(i))
    except Exception as e :
                pass
# Out:
# 0 is : cat
# 1 is : cat
# 2 is : cat
# 3 is : dog
# 4 is : cat
# 5 is : cat
# 6 is : cat
# 7 is : cat
# 8 is : cat
# 9 is : cat
# 10 is : cat
# 11 is : cat
# 12 is : cat
# 13 is : cat
# 14 is : cat
# 15 is : cat
# 16 is : cat
# 17 is : cat
# 18 is : dog
# 19 is : cat
# 20 is : cat
# 21 is : cat
# 22 is : cat
# 23 is : cat
# 24 is : cat
# 25 is : cat
# 26 is : cat
# 27 is : cat
# 28 is : cat
# 29 is : cat
# 30 is : cat
# 31 is : cat
# 32 is : cat
# 33 is : cat
# 34 is : cat
# 35 is : cat
# 36 is : cat
# 37 is : cat
# 38 is : cat
# 39 is : cat
# 40 is : dog
# 41 is : cat
# 42 is : cat
# 43 is : dog
# 44 is : cat
# 45 is : cat
# 46 is : cat
# 47 is : cat
# 48 is : cat
# 49 is : cat
# 50 is : cat
# 51 is : cat
# 52 is : cat
# 53 is : cat
# 54 is : cat
# 55 is : cat
# 56 is : cat
# 57 is : cat
# 58 is : cat
# 59 is : cat
# 60 is : cat
# 61 is : cat
# 62 is : cat
# 63 is : cat
# 64 is : cat
# 65 is : dog
# 66 is : cat
# 67 is : dog
# 68 is : cat
# 69 is : cat
# 70 is : cat
# 71 is : cat
# ...

# %%
sum         # 11233 cats predicted from 12500cats -90%
# Out:
# 11233

# %%
sum1=0
for i in range(0,12500) :
    photo = "PetImages/Dog/{}.jpg".format(i)
    try :
        pic_array = cv2.imread(photo, cv2.IMREAD_GRAYSCALE)
        new_array = cv2.resize(pic_array,(IMG_SIZE,IMG_SIZE))

        img_batch = np.expand_dims(new_array, axis=0)
        uimg = np.resize(img_batch,(1,50,50,1))

        uimg = uimg/255.0
        pred = model.predict(uimg)

        pred
        if pred[0][0]>0.5 : 
            print("{} is : cat".format(i))
            sum1 +=1
        else :
            print("{} is : dog".format(i))
    except Exception as e :
                pass
# Out:
# 0 is : dog
# 1 is : dog
# 2 is : dog
# 3 is : dog
# 4 is : dog
# 5 is : dog
# 6 is : dog
# 7 is : dog
# 8 is : dog
# 9 is : dog
# 10 is : dog
# 11 is : dog
# 12 is : dog
# 13 is : dog
# 14 is : dog
# 15 is : dog
# 16 is : dog
# 17 is : dog
# 18 is : dog
# 19 is : dog
# 20 is : dog
# 21 is : dog
# 22 is : dog
# 23 is : cat
# 24 is : dog
# 25 is : dog
# 26 is : dog
# 27 is : dog
# 28 is : dog
# 29 is : dog
# 30 is : dog
# 31 is : dog
# 32 is : dog
# 33 is : dog
# 34 is : dog
# 35 is : dog
# 36 is : dog
# 37 is : dog
# 38 is : dog
# 39 is : dog
# 40 is : dog
# 41 is : dog
# 42 is : dog
# 43 is : dog
# 44 is : dog
# 45 is : dog
# 46 is : dog
# 47 is : dog
# 48 is : cat
# 49 is : dog
# 50 is : dog
# 51 is : dog
# 52 is : dog
# 53 is : dog
# 54 is : cat
# 55 is : dog
# 56 is : dog
# 57 is : dog
# 58 is : dog
# 59 is : dog
# 60 is : dog
# 61 is : dog
# 62 is : dog
# 63 is : dog
# 64 is : dog
# 65 is : dog
# 66 is : dog
# 67 is : dog
# 68 is : dog
# 69 is : dog
# 70 is : dog
# 71 is : dog
# ...

# %%
sum1# number of dogs (11677 dogs predicted in 12500 dogs-94%)
# Out:
# 823
